# %%
# Representasi State Space dalam bentuk Dictionary
# Titik kiri adalah lokasi saat ini, titik kanan adalah cabang jalan yang bisa dilalui
graph = {
    'A': ['B', 'C'],
    'B': ['D', 'E'],
    'C': ['F'],
    'D': [],
    'E': ['F'],
    'F': []
}

# 1. Algoritma Breadth-First Search (BFS)
def bfs_search(graph, start, goal):
    visited = []      # Catatan jalan yang sudah dilewati
    queue = [start]   # Antrean pengecekan (Queue)

    print("Mulai penelusuran BFS:")
    while queue:
        # Ambil elemen PERTAMA dari antrean (Indeks 0)
        node = queue.pop(0) 
        
        if node not in visited:
            print(f"Mengunjungi node: {node}")
            visited.append(node)
            
            # Jika goal ditemukan, berhenti
            if node == goal:
                print("🏁 GOAL DITEMUKAN!")
                return visited
            
            # Masukkan semua tetangga node ini ke dalam antrean
            for tetangga in graph[node]:
                if tetangga not in visited:
                    queue.append(tetangga)
                    
    print("Goal tidak ditemukan.")
    return visited

# --- JALANKAN PROGRAM ---
print("--- Hasil BFS ---")
bfs_hasil = bfs_search(graph, 'A', 'F')
print("Jalur BFS:", bfs_hasil)
print("\n")

# ==========================================
# TUGAS KALIAN:
# Buat fungsi dfs_search() di bawah ini!
# Clue: Ubah bagian 'queue.pop(0)' menjadi logika Stack (mengambil data TERAKHIR)
# ==========================================



# 2. Algoritma Depth-First Search (DFS)
def dfs_search(graph, start, goal):
    visited = []      # Catatan jalan yang sudah dilewati
    stack = [start]   # Antrean pengecekan dari yang baru datang(stack)

    print("Mulai penelusuran DFS:")
    while stack:
        # Ambil elemen TERAKHIR dari antrean (pop() tidak bervalue)
        node = stack.pop() # pakai stack karena merupakan sebuah konsep LIFO(Last In – Last Out dan juga kenapa method pop() nya kosong karena kita mengambil nya dari elemen yang paling terakhir
        
        if node not in visited:
            print(f"Mengunjungi node: {node}")
            visited.append(node)
            
            # Jika goal ditemukan, berhenti
            if node == goal:
                print("🏁 GOAL DITEMUKAN!")
                return visited
            
            # Masukkan semua tetangga node ini ke dalam antrean
            for tetangga in graph[node]:
                if tetangga not in visited:
                    stack.append(tetangga)
                    
    print("Goal tidak ditemukan.")
    return visited

# --- JALANKAN PROGRAM ---
print("--- Hasil DFS ---")
dfs_hasil = dfs_search(graph, 'A', 'F')
print("Jalur DFS:", dfs_hasil)
print("\n")
# Out:
# --- Hasil BFS ---
# Mulai penelusuran BFS:
# Mengunjungi node: A
# Mengunjungi node: B
# Mengunjungi node: C
# Mengunjungi node: D
# Mengunjungi node: E
# Mengunjungi node: F
# 🏁 GOAL DITEMUKAN!
# Jalur BFS: ['A', 'B', 'C', 'D', 'E', 'F']
#
#
# --- Hasil DFS ---
# Mulai penelusuran DFS:
# Mengunjungi node: A
# Mengunjungi node: C
# Mengunjungi node: F
# 🏁 GOAL DITEMUKAN!
# Jalur DFS: ['A', 'C', 'F']
